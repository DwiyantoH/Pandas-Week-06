# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.3.4

# %%
df = pd.read_csv(r'C:\Users\ACER\Downloads\titanicfull.csv')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
df.groupby('pclass')['sex'] .count() .to_frame()
# Out:
#         sex
# pclass
# 1       323
# 2       277
# 3       709

# %%
df.groupby('pclass')['parch'] .mean().to_frame()
# Out:
#            parch
# pclass
# 1       0.365325
# 2       0.368231
# 3       0.400564

# %%
df.groupby('pclass')['parch'] .median() .to_frame()
# Out:
#         parch
# pclass
# 1         0.0
# 2         0.0
# 3         0.0

# %%
df.groupby('pclass')[ 'parch' ] .agg(['count', 'mean', 'median' ])
# Out:
#         count      mean  median
# pclass
# 1         323  0.365325     0.0
# 2         277  0.368231     0.0
# 3         709  0.400564     0.0

# %%
df.groupby('pclass')['parch'] .describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# pclass
# 1       323.0  0.365325  0.715602  0.0  0.0  0.0  0.5  4.0
# 2       277.0  0.368231  0.692717  0.0  0.0  0.0  1.0  3.0
# 3       709.0  0.400564  0.981639  0.0  0.0  0.0  0.0  9.0
